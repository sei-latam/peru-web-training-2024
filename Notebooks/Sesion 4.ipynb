# %% [markdown]
# # Parametrizacion de hidrologia en WEAP

# %% [markdown]
# En el modelo de la reunion pasada, ajustar el esquema como se muestra en la siguiente figura:
# <img src="https://drive.google.com/uc?export=view&id=1LW7nNmVophKTFoftd2X-kwRfS9B9edN-" alt="Drawing"  width="400" style="width: 100px;"/>
#
# En resultados buscar el reporte "Streamflow Gauge Comparisson" y guardar como una reporte de "Favorites" en el Menu de WEAP
#
# <img src="https://drive.google.com/uc?export=view&id=12_WMuvBBFsA7Td3rn0xcelv-5AkcCV8z" alt="Drawing"  width="400" style="width: 100px;"/>
#
# En el ramal de datos “Key Assumptions”, se debe crear una estructura de parámetros de acuerdo al método o modelos aplicado, en nuestro caso **“metodo de humedad de suelo”**. La estructura de dependencias permite apilar clasificaciones en una estructura tipo “árbol de datos”
#
# <img src="https://drive.google.com/uc?export=view&id=1xvoSZ0bZ04pQvvgvDk69ge8gBiVumwTi" alt="Drawing"  width="400" style="width: 100px;"/>
#
# Los parametros del modelo en el presente proyecto cuentan con valores referenciales obtenidos de reportes tecnicos y estudios tecnicos en el campo de la hidrologia aplicada utiliando el modelo WEAP.
#
#
# <img src="https://drive.google.com/uc?export=view&id=1XYb1RiV_bJIVyH3WrzUfHk_LS8bi0cBR" alt="Drawing"  width="400" style="width: 100px;"/>
#
#
# <img src="https://drive.google.com/uc?export=view&id=1aorTV5BmY94CyyZgbbt_rgLgx1JFSGZz" alt="Drawing"  width="400" style="width: 100px;"/>
#
#
# <img src="https://drive.google.com/uc?export=view&id=1df1u3hz4AUpQ0B01Q7xnN_3HIZTR17ci" alt="Drawing"  width="400" style="width: 100px;"/>
#
# La parametrizacion en WEAP consiste en organizar la estructura de parametros del modelo hidrologico en la rama "Key Assumptions"y asignar los valores de las tablas previamente descritas.
#
#
# <img src="https://drive.google.com/uc?export=view&id=1vBz4qoFqU06YGRp0TKcXg4mPIPBVs5Od" alt="Drawing"  width="400" style="width: 100px;"/>
#
# Una vez concluida estos pasos, se utilizara la herramienta "Export expressions to Excel" e "Import expressions to Excel" para relacionar los parametros de "Key Assumption" con las cuencas simuladas del ejercicio.
#
# <img src="https://drive.google.com/uc?export=view&id=1-clhMv17oTAAY8I-gF1hkoz1OcDa9xfv" alt="Drawing"  width="400" style="width: 100px;"/>
#
# Este procedimiento tambien nos ayudara en la cuantificacion de las condiciones iniciales para el modelo, vale decir las humedades en zona radicular $h_1$, y contenido de agua en la zona subterranea $h_2$.

# %% [markdown]
# # Analisis de sensibilidad de un modelo hidrologico

# %%
from IPython.core.display import display, HTML
# Google Drive file ID
file_id = "1eys3RBMVGQixApC6GECmVg7DnoUPfyLj"
embed_url = f"https://drive.google.com/file/d/{file_id}/preview"
# Define the HTML content with a resizable iframe
html_content = f"""<!DOCTYPE html><html><head><style>.resizable {{resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}}</style></head><body><div class="resizable" style="height: 500px;"><iframe src="{embed_url}" width="100%" height="100%" frameborder="0"></iframe>
</div><p>If the file does not load, <a href="https://drive.google.com/file/d/{file_id}/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 500px;"><iframe src="https://drive.google.com/file/d/1eys3RBMVGQixApC6GECmVg7DnoUPfyLj/preview" width="100%" height="100%" frameborder="0"></iframe>
# </div><p>If the file does not load, <a href="https://drive.google.com/file/d/1eys3RBMVGQixApC6GECmVg7DnoUPfyLj/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>

# %%
from IPython.core.display import display, HTML
# Google Drive file ID
file_id = "1vCUq045mGfATufffLT3ieX276SZJiWOT"
embed_url = f"https://drive.google.com/file/d/{file_id}/preview"
# Define the HTML content with a resizable iframe
html_content = f"""<!DOCTYPE html><html><head><style>.resizable {{resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}}</style></head><body><div class="resizable" style="height: 300px;"><iframe src="{embed_url}" width="100%" height="100%" frameborder="0"></iframe>
</div><p>If the file does not load, <a href="https://drive.google.com/file/d/{file_id}/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 300px;"><iframe src="https://drive.google.com/file/d/1vCUq045mGfATufffLT3ieX276SZJiWOT/preview" width="100%" height="100%" frameborder="0"></iframe>
# </div><p>If the file does not load, <a href="https://drive.google.com/file/d/1vCUq045mGfATufffLT3ieX276SZJiWOT/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>

# %% [markdown]
# # Calibracion de un modelo hidrologico

# %%
from IPython.core.display import display, HTML
# Define the HTML content with a resizable iframe
html_content = """<!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 600px;"><iframe src="https://doi-bor.github.io/ostrich/" width="100%" height="100%" frameborder="0"></iframe></div></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 600px;"><iframe src="https://doi-bor.github.io/ostrich/" width="100%" height="100%" frameborder="0"></iframe></div></body></html>

# %% [markdown]
# # Escenarios en modelacion utilizando WEAP

# %% [markdown]
# ## Cambio Climatico

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1n-LQv0pjNBOeDqvDv0qhtD7bIZh0dTtG" alt="Drawing"  width="400" style="width: 100px;"/>
#
# <img src="https://drive.google.com/uc?export=view&id=1iknrJAy6w4FvzgLPyhTXyQwEoDhq-p3Q" alt="Drawing"  width="400" style="width: 100px;"/>
#
# <img src="https://drive.google.com/uc?export=view&id=1BEShQyvceite1HLJM3DLKSANTbKVW0sg" alt="Drawing"  width="400" style="width: 100px;"/>
#
# <img src="https://drive.google.com/uc?export=view&id=12NSt6a3GaO6GQd29GyXoDOafRcnhrcQp" alt="Drawing"  width="400" style="width: 100px;"/>
#
# <img src="https://drive.google.com/uc?export=view&id=10wSW0gp1Wmm0p7UI3ES_cSSmKIJxOj3a" alt="Drawing"  width="800" style="width: 100px;"/>
#
# <img src="https://drive.google.com/uc?export=view&id=1V_NKv-Ph3kSd9cwICx_Trz2Ys5KmoFkG" alt="Drawing"  width="800" style="width: 100px;"/>
