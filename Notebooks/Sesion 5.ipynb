# %%
from IPython.core.display import display, HTML
# Google Drive file ID
file_id = "1x490W7kZAFpzG4siwS3LBMy3mtgN75h0"
embed_url = f"https://drive.google.com/file/d/{file_id}/preview"
# Define the HTML content with a resizable iframe
html_content = f"""<!DOCTYPE html><html><head><style>.resizable {{resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}}</style></head><body><div class="resizable" style="height: 400px;"><iframe src="{embed_url}" width="100%" height="100%" frameborder="0"></iframe>
</div><p>If the file does not load, <a href="https://drive.google.com/file/d/{file_id}/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 400px;"><iframe src="https://drive.google.com/file/d/1x490W7kZAFpzG4siwS3LBMy3mtgN75h0/preview" width="100%" height="100%" frameborder="0"></iframe>
# </div><p>If the file does not load, <a href="https://drive.google.com/file/d/1x490W7kZAFpzG4siwS3LBMy3mtgN75h0/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>

# %%
from IPython.core.display import display, HTML
# Google Drive file ID
file_id = "1XPkdi1cVQ4xCUmYAzK-oYSzslnBoieqs"
embed_url = f"https://drive.google.com/file/d/{file_id}/preview"
# Define the HTML content with a resizable iframe
html_content = f"""<!DOCTYPE html><html><head><style>.resizable {{resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}}</style></head><body><div class="resizable" style="height: 400px;"><iframe src="{embed_url}" width="100%" height="100%" frameborder="0"></iframe>
</div><p>If the file does not load, <a href="https://drive.google.com/file/d/{file_id}/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 400px;"><iframe src="https://drive.google.com/file/d/1XPkdi1cVQ4xCUmYAzK-oYSzslnBoieqs/preview" width="100%" height="100%" frameborder="0"></iframe>
# </div><p>If the file does not load, <a href="https://drive.google.com/file/d/1XPkdi1cVQ4xCUmYAzK-oYSzslnBoieqs/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>
