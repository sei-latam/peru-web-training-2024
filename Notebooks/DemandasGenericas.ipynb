# %% [markdown]
# # Recapitulación de avance en el modelo del entrenamiento

# %% [markdown]
# En la seccion previa se avanzo en la delimitación de cuencas que seran utilizadas para la descripción de los diferentes componentes de cálculo que pueden ser desarrollados en WEAP. El modelo debe contar con los siguientes elementos:
#
# <img src="https://drive.google.com/uc?export=view&id=1y7MX51tzMlyOLXONWfuDTrU4a8q61je0" alt="Drawing"  width="1000" style="width: 100px;"/>
#
# Si en caso, no tenga el modelo en ese avance, se recomienda descargar una version actualizada en el siguiente enlace:

# %%
from IPython.core.display import display, HTML
# Google Drive file ID
file_id = "1skE2zQdOCVKUj5z0zcJ3_gcfQpEVVTdL"
embed_url = f"https://drive.google.com/file/d/{file_id}/preview"
# Define the HTML content with a resizable iframe
html_content = f"""<!DOCTYPE html><html><head><style>.resizable {{resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}}</style></head><body><div class="resizable" style="height: 400px;"><iframe src="{embed_url}" width="100%" height="100%" frameborder="0"></iframe>
</div><p>If the file does not load, <a href="https://drive.google.com/file/d/{file_id}/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 400px;"><iframe src="https://drive.google.com/file/d/1skE2zQdOCVKUj5z0zcJ3_gcfQpEVVTdL/preview" width="100%" height="100%" frameborder="0"></iframe>
# </div><p>If the file does not load, <a href="https://drive.google.com/file/d/1skE2zQdOCVKUj5z0zcJ3_gcfQpEVVTdL/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>

# %% [markdown]
# # Preparación y edición de una demanda de agua

# %% [markdown]
# WEAP permite ajustar los elementos de demanda de acuerdo con la informacion que el modelador tenga. En los pasos siguientes se guiara en la creacion de los dos nodos de demanda de ejemplo para la region del rio Tumbes, mejorando la configuracion de WEAP para ingresar datos de demanda agricola mas especificos, pero manteniendo la metodologia previa en el caso de la demanda poblacional.
#
# <img src="https://drive.google.com/uc?export=view&id=1G7vOPUImsNPivm1RzuqLSlX7WT82ZARo" alt="Drawing"  width="1000" style="width: 100px;"/>

# %% [markdown]
# El modelo con los metodos de representacion tambien permiten definir patrones por paso de tiempo [dia, mensual,anual] en la cual el modelo este desarrollado. En el presente ejemplo, se proporciona el siguiente archivo obtenido con los patrones de consumo mensual de las zonas agricolas obtenidos a traves de indices de vegetacion entre el 2000 al 2020.
#
# La visualizacion y descarga del archivo es el siguiente:

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# datos<-read.csv("https://drive.google.com/uc?export=download&id=1JVnbFEms9EQfxM0GpSB_L3NaLRu3xarr", header = TRUE)
# datos<-as.data.frame(datos[2:nrow(datos),])
# plot(as.Date(datos$X.DateFormat.mm.dd.yyyy, format = "%m/%d/%Y"), datos$X, type = "l", xlab= "años", ylab = "Porcentaje de uso mensual")

# %%
from IPython.core.display import display, HTML
# Google Drive file ID
file_id = "1JVnbFEms9EQfxM0GpSB_L3NaLRu3xarr"
embed_url = f"https://drive.google.com/file/d/{file_id}/preview"
# Define the HTML content with a resizable iframe
html_content = f"""<!DOCTYPE html><html><head><style>.resizable {{resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}}</style></head><body><div class="resizable" style="height: 200px;"><iframe src="{embed_url}" width="100%" height="100%" frameborder="0"></iframe>
</div><p>If the file does not load, <a href="https://drive.google.com/file/d/{file_id}/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>"""
# Display the HTML content in the notebook
display(HTML(html_content))
# Out:
# <!DOCTYPE html><html><head><style>.resizable {resize: vertical;overflow: auto;width: 100%;border: 1px solid black;}</style></head><body><div class="resizable" style="height: 200px;"><iframe src="https://drive.google.com/file/d/1JVnbFEms9EQfxM0GpSB_L3NaLRu3xarr/preview" width="100%" height="100%" frameborder="0"></iframe>
# </div><p>If the file does not load, <a href="https://drive.google.com/file/d/1JVnbFEms9EQfxM0GpSB_L3NaLRu3xarr/view?usp=sharing" target="_blank">click here to view it on Google Drive</a>.</p></body></html>

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1HEWk_W9Oh1jZdJ8s7R8jTlEYV4WNeUn8" alt="Drawing"  width="1000" style="width: 100px;"/>
